# %% [markdown]
# <a href="https://colab.research.google.com/github/riddhikaa/sign_language/blob/main/Copy_of_Project_Draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ["KAGGLE_USERNAME"]="palak27"
os.environ["KAGGLE_KEY"] = "a9c6366cd0407ac517d026e146957691"
# !kaggle datasets download vaishnaviasonawane/indian-sign-language-dataset
# Out:
# indian-sign-language-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
from IPython.display import clear_output
# !unzip indian-sign-language-dataset.zip
clear_output()

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Reshape, Dropout, Dense
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Activation, ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
import numpy as np
from PIL import Image
from tqdm import tqdm
import os
import time
import matplotlib.pyplot as plt

# %%
GENERATE_RES = 3 # Generation resolution factor
# (1=32, 2=64, 3=96, 4=128, etc.)
GENERATE_SQUARE = 32 * GENERATE_RES # rows/cols (should be square)
IMAGE_CHANNELS = 3

# Preview image
PREVIEW_ROWS = 4
PREVIEW_COLS = 7
PREVIEW_MARGIN = 16

# Size vector to generate images from
SEED_SIZE = 100

# Configuration
DATA_PATH1 = '/content/data/1'
EPOCHS = 50
BATCH_SIZE = 32
BUFFER_SIZE = 60000

# %%
training_binary_path = os.path.join(DATA_PATH1,
        f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}.npy')

print(f"Looking for file: {training_binary_path}")

if not os.path.isfile(training_binary_path):
  start = time.time()
  print("Loading training images...")

  training_data = []
  faces_path = os.path.join(DATA_PATH1)
  for filename in tqdm(os.listdir(faces_path)):
      path = os.path.join(faces_path,filename)
      image = Image.open(path).resize((GENERATE_SQUARE,
            GENERATE_SQUARE),Image.ANTIALIAS)
      training_data.append(np.asarray(image))
  training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,
            GENERATE_SQUARE,IMAGE_CHANNELS))
  training_data = training_data.astype(np.float32)
  training_data = training_data / 127.5 - 1.


  print("Saving training image binary...")
  np.save(training_binary_path,training_data)
  elapsed = time.time()-start
 # print (f'Image preprocess time:{hms_string(elapsed)}')
else:
  print("Loading previous training pickle...")
  training_data = np.load(training_binary_path)
# Out:
# Looking for file: /content/data/1/training_data_96_96.npy
# Loading previous training pickle...

# %%
train_dataset1 = tf.data.Dataset.from_tensor_slices(training_data).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
def build_generator(seed_size, channels):
    model = Sequential()

    model.add(Dense(4*4*256,activation="relu",input_dim=seed_size))
    model.add(Reshape((4,4,256)))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    # Output resolution, additional upsampling
    model.add(UpSampling2D())
    model.add(Conv2D(128,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    if GENERATE_RES>1:
      model.add(UpSampling2D(size=(GENERATE_RES,GENERATE_RES)))
      model.add(Conv2D(128,kernel_size=3,padding="same"))
      model.add(BatchNormalization(momentum=0.8))
      model.add(Activation("relu"))

    # Final CNN layer
    model.add(Conv2D(channels,kernel_size=3,padding="same"))
    model.add(Activation("tanh"))

    return model

# %%
def build_discriminator(image_shape):
    model = Sequential()

    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=image_shape,
                     padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(512, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))

    return model

# %%
def save_images(cnt,noise,datapath):
  image_array = np.full((
      PREVIEW_MARGIN + (PREVIEW_ROWS * (GENERATE_SQUARE+PREVIEW_MARGIN)),
      PREVIEW_MARGIN + (PREVIEW_COLS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 3),
      255, dtype=np.uint8)

  generated_images = generator.predict(noise)

  generated_images = 0.5 * generated_images + 0.5
  image_count = 0
  for row in range(PREVIEW_ROWS):
      for col in range(PREVIEW_COLS):
        r = row * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        c = col * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        image_array[r:r+GENERATE_SQUARE,c:c+GENERATE_SQUARE] = generated_images[image_count] * 255
        image_count += 1


  output_path = os.path.join(datapath,'output')
  if not os.path.exists(output_path):
    os.makedirs(output_path)

  filename = os.path.join(output_path,f"train-{cnt}.png")
  im = Image.fromarray(image_array)
  im.save(filename)
generator = build_generator(SEED_SIZE, IMAGE_CHANNELS)

noise = tf.random.normal([1, SEED_SIZE])
generated_image = generator(noise, training=False)

plt.imshow(generated_image[0, :, :, 0])

# %%
image_shape = (GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS)

discriminator = build_discriminator(image_shape)
decision = discriminator(generated_image)
print (decision)
# Out:
# tf.Tensor([[0.4994533]], shape=(1, 1), dtype=float32)

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy()

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
generator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)

# %%
@tf.function
def train_step(images):
  seed = tf.random.normal([BATCH_SIZE, SEED_SIZE])

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator(seed, training=True)

    real_output = discriminator(images, training=True)
    fake_output = discriminator(generated_images, training=True)

    gen_loss = generator_loss(fake_output)
    disc_loss = discriminator_loss(real_output, fake_output)


    gradients_of_generator = gen_tape.gradient(
        gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(
        disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(
        gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(
        gradients_of_discriminator,
        discriminator.trainable_variables))
  return gen_loss,disc_loss

# %%
def train(dataset, epochs,datapath):
  fixed_seed = np.random.normal(0, 1, (PREVIEW_ROWS * PREVIEW_COLS,
                                       SEED_SIZE))
  start = time.time()

  for epoch in range(epochs):
    epoch_start = time.time()

    gen_loss_list = []
    disc_loss_list = []

    for image_batch in dataset:
      t = train_step(image_batch)
      gen_loss_list.append(t[0])
      disc_loss_list.append(t[1])

    g_loss = sum(gen_loss_list) / len(gen_loss_list)
    d_loss = sum(disc_loss_list) / len(disc_loss_list)

    epoch_elapsed = time.time()-epoch_start
    print (f'Epoch{epoch+1}, gen loss={g_loss},disc loss={d_loss},'
           '{hms_string(epoch_elapsed)}')
    save_images(epoch,fixed_seed,datapath)

  elapsed = time.time()-start
  #print (f'Training time: {hms_string(elapsed)}')
train(train_dataset1, EPOCHS,DATA_PATH1)
# Out:
# Epoch1, gen loss=3.5080149173736572,disc loss=0.2972696125507355,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 1s 1s/step
# Epoch2, gen loss=3.872629165649414,disc loss=0.4837125837802887,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 22ms/step
# Epoch3, gen loss=3.2221386432647705,disc loss=0.7181506752967834,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch4, gen loss=2.8870689868927,disc loss=0.7516369819641113,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch5, gen loss=2.9891715049743652,disc loss=0.8528887033462524,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 35ms/step
# Epoch6, gen loss=3.062084436416626,disc loss=0.8918594717979431,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch7, gen loss=2.952829360961914,disc loss=0.7561168670654297,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 36ms/step
# Epoch8, gen loss=3.2222793102264404,disc loss=0.8072987198829651,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 24ms/step
# Epoch9, gen loss=3.165024757385254,disc loss=0.6572579145431519,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch10, gen loss=3.110109329223633,disc loss=0.751416802406311,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 21ms/step
# Epoch11, gen loss=3.3556602001190186,disc loss=0.7969158291816711,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch12, gen loss=3.2977874279022217,disc loss=0.7164783477783203,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 31ms/step
# Epoch13, gen loss=3.6357944011688232,disc loss=0.714528501033783,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch14, gen loss=3.967475175857544,disc loss=0.8203001618385315,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch15, gen loss=3.8271138668060303,disc loss=0.5050206184387207,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch16, gen loss=4.135664463043213,disc loss=0.8236228823661804,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch17, gen loss=4.168355464935303,disc loss=0.8073435425758362,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch18, gen loss=4.352476119995117,disc loss=0.7207760810852051,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch19, gen loss=4.437798500061035,disc loss=0.6693695187568665,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 32ms/step
# Epoch20, gen loss=4.555583953857422,disc loss=0.4741073548793793,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 17ms/step
# Epoch21, gen loss=5.524418354034424,disc loss=0.826400637626648,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 23ms/step
# Epoch22, gen loss=4.162367343902588,disc loss=0.526542067527771,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch23, gen loss=4.628674030303955,disc loss=0.363041490316391,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 30ms/step
# Epoch24, gen loss=5.454904556274414,disc loss=0.530542254447937,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 25ms/step
# Epoch25, gen loss=5.460189342498779,disc loss=0.857694149017334,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch26, gen loss=4.618945121765137,disc loss=0.4367491602897644,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 31ms/step
# Epoch27, gen loss=4.642673969268799,disc loss=0.7152698040008545,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 26ms/step
# Epoch28, gen loss=4.431816577911377,disc loss=0.6082886457443237,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch29, gen loss=5.669612407684326,disc loss=0.7655028700828552,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch30, gen loss=4.357809543609619,disc loss=0.4762820303440094,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch31, gen loss=5.106040954589844,disc loss=0.46257635951042175,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch32, gen loss=5.998043537139893,disc loss=0.9503188133239746,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch33, gen loss=5.273473262786865,disc loss=0.851486325263977,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 32ms/step
# Epoch34, gen loss=4.430335998535156,disc loss=0.6791691184043884,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch35, gen loss=5.380454063415527,disc loss=0.5979111194610596,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 26ms/step
# Epoch36, gen loss=5.324190616607666,disc loss=0.8463733792304993,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch37, gen loss=4.398635387420654,disc loss=0.4499378800392151,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 17ms/step
# Epoch38, gen loss=6.027629375457764,disc loss=0.891712486743927,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch39, gen loss=4.350252151489258,disc loss=0.32052838802337646,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch40, gen loss=4.430821418762207,disc loss=0.41576024889945984,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch41, gen loss=5.48216438293457,disc loss=0.7197698950767517,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 28ms/step
# Epoch42, gen loss=5.9094157218933105,disc loss=0.5235943794250488,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 27ms/step
# Epoch43, gen loss=5.199520111083984,disc loss=0.5371813774108887,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 21ms/step
# Epoch44, gen loss=5.010421276092529,disc loss=0.4323127269744873,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch45, gen loss=5.052611351013184,disc loss=0.44652828574180603,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch46, gen loss=5.428502082824707,disc loss=0.34770461916923523,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 22ms/step
# Epoch47, gen loss=5.111762523651123,disc loss=0.5377053022384644,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch48, gen loss=6.537877082824707,disc loss=0.5333195924758911,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch49, gen loss=4.476108551025391,disc loss=0.2606556713581085,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 38ms/step
# Epoch50, gen loss=6.233793258666992,disc loss=0.46123006939888,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step

# %%
images_len=os.listdir(DATA_PATH1)
len(images_len)
# Out:
# 1202

# %%
imgpath="/content/data/1/output/train-22.png"
Image.open(imgpath)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x464>

# %%
root_dir="/content/data"
class_names=os.listdir(root_dir)
for name in class_names:
  path=root_dir+"/"+name
  n_images=len(os.listdir(path))
  print(name," : ",n_images)
# Out:
# G  :  1200
# 2  :  1200
# V  :  1200
# L  :  1200
# P  :  1200
# 3  :  1200
# O  :  1200
# 4  :  1200
# F  :  1200
# C  :  1200
# N  :  1200
# M  :  1200
# W  :  1200
# Y  :  1200
# K  :  1200
# 9  :  1200
# S  :  1200
# D  :  1200
# 5  :  1200
# T  :  1200
# I  :  1200
# U  :  1200
# 8  :  1200
# 6  :  1200
# B  :  1200
# J  :  1200
# A  :  1200
# 7  :  1200
# Q  :  1200
# 1  :  1202
# H  :  1200
# R  :  1200
# X  :  1200
# E  :  1200
# Z  :  1200

# %%
DATA_PATH8="/content/data/8"
training_binary_path = os.path.join(DATA_PATH8,
        f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}.npy')

print(f"Looking for file: {training_binary_path}")

if not os.path.isfile(training_binary_path):
  start = time.time()
  print("Loading training images...")

  training_data = []
  faces_path = os.path.join(DATA_PATH8)
  for filename in tqdm(os.listdir(faces_path)):
      path = os.path.join(faces_path,filename)
      image = Image.open(path).resize((GENERATE_SQUARE,
            GENERATE_SQUARE),Image.ANTIALIAS)
      training_data.append(np.asarray(image))
  training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,
            GENERATE_SQUARE,IMAGE_CHANNELS))
  training_data = training_data.astype(np.float32)
  training_data = training_data / 127.5 - 1.


  print("Saving training image binary...")
  np.save(training_binary_path,training_data)
  elapsed = time.time()-start
  #print (f'Image preprocess time:{hms_string(elapsed)}')
else:
  print("Loading previous training pickle...")
  training_data = np.load(training_binary_path)
# Out:
# Looking for file: /content/data/8/training_data_96_96.npy
# Loading previous training pickle...

# %%
train_dataset8 = tf.data.Dataset.from_tensor_slices(training_data).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
train(train_dataset8, EPOCHS,DATA_PATH8)
# Out:
# Epoch1, gen loss=5.294985294342041,disc loss=2.102684736251831,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch2, gen loss=9.252527236938477,disc loss=2.153071880340576,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch3, gen loss=9.374547004699707,disc loss=1.3764690160751343,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 34ms/step
# Epoch4, gen loss=9.551616668701172,disc loss=0.7753162980079651,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch5, gen loss=9.500897407531738,disc loss=1.0485029220581055,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 20ms/step
# Epoch6, gen loss=7.258779525756836,disc loss=0.8218328356742859,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 21ms/step
# Epoch7, gen loss=8.480599403381348,disc loss=1.0879675149917603,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 21ms/step
# Epoch8, gen loss=6.865833282470703,disc loss=0.7561424374580383,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 34ms/step
# Epoch9, gen loss=7.743557453155518,disc loss=0.6711987853050232,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch10, gen loss=8.969586372375488,disc loss=1.1470028162002563,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch11, gen loss=6.921606063842773,disc loss=0.7598709464073181,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch12, gen loss=7.7012481689453125,disc loss=0.6128405332565308,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 24ms/step
# Epoch13, gen loss=6.5945725440979,disc loss=0.36726289987564087,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 20ms/step
# Epoch14, gen loss=6.004390716552734,disc loss=0.5289217233657837,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 26ms/step
# Epoch15, gen loss=5.80830192565918,disc loss=0.6940732002258301,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 29ms/step
# Epoch16, gen loss=6.53700590133667,disc loss=0.9046497344970703,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch17, gen loss=4.9011969566345215,disc loss=0.3509119749069214,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 21ms/step
# Epoch18, gen loss=7.367565631866455,disc loss=0.6239975094795227,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch19, gen loss=6.526007175445557,disc loss=0.3420961797237396,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 17ms/step
# Epoch20, gen loss=4.875804901123047,disc loss=0.32941481471061707,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch21, gen loss=5.172871112823486,disc loss=0.21700023114681244,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 20ms/step
# Epoch22, gen loss=4.320001602172852,disc loss=0.22931919991970062,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 39ms/step
# Epoch23, gen loss=5.464247703552246,disc loss=0.21912747621536255,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 22ms/step
# Epoch24, gen loss=4.962457656860352,disc loss=0.2898963391780853,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 23ms/step
# Epoch25, gen loss=5.914378643035889,disc loss=0.14531417191028595,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch26, gen loss=6.581453323364258,disc loss=0.09712298214435577,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch27, gen loss=4.935905456542969,disc loss=0.13988609611988068,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch28, gen loss=5.419853210449219,disc loss=0.11572208255529404,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch29, gen loss=5.066000938415527,disc loss=0.24121741950511932,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 33ms/step
# Epoch30, gen loss=6.922290325164795,disc loss=0.29803916811943054,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 22ms/step
# Epoch31, gen loss=5.22197961807251,disc loss=0.11902953684329987,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch32, gen loss=4.76330041885376,disc loss=0.14336083829402924,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch33, gen loss=5.26884126663208,disc loss=0.12611432373523712,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch34, gen loss=5.99682092666626,disc loss=0.1291375458240509,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch35, gen loss=6.863896369934082,disc loss=0.0803530141711235,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch36, gen loss=4.978870391845703,disc loss=0.1461285948753357,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 32ms/step
# Epoch37, gen loss=5.25529670715332,disc loss=0.10240872949361801,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch38, gen loss=5.609726428985596,disc loss=0.059408657252788544,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 21ms/step
# Epoch39, gen loss=5.489131927490234,disc loss=0.06607033312320709,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch40, gen loss=5.548122882843018,disc loss=0.06209643930196762,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch41, gen loss=6.290125846862793,disc loss=0.03890020400285721,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch42, gen loss=6.819441795349121,disc loss=0.041264548897743225,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 20ms/step
# Epoch43, gen loss=6.382857799530029,disc loss=0.048373207449913025,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 30ms/step
# Epoch44, gen loss=7.153692245483398,disc loss=0.02614654041826725,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch45, gen loss=6.835751056671143,disc loss=0.0352289155125618,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch46, gen loss=5.700319290161133,disc loss=0.06272947788238525,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch47, gen loss=5.605391979217529,disc loss=0.051787957549095154,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch48, gen loss=6.032039642333984,disc loss=0.038564011454582214,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch49, gen loss=6.200827121734619,disc loss=0.11075858026742935,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch50, gen loss=6.5020751953125,disc loss=0.05661248043179512,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 30ms/step

# %%
imgpath="/content/data/8/output/train-23.png"
Image.open(imgpath)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x464>

# %%
DATA_PATHM="/content/data/M"
training_binary_path = os.path.join(DATA_PATHM,
        f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}.npy')

print(f"Looking for file: {training_binary_path}")

if not os.path.isfile(training_binary_path):
  start = time.time()
  print("Loading training images...")

  training_data = []
  faces_path = os.path.join(DATA_PATHM)
  for filename in tqdm(os.listdir(faces_path)):
      path = os.path.join(faces_path,filename)
      image = Image.open(path).resize((GENERATE_SQUARE,
            GENERATE_SQUARE),Image.ANTIALIAS)
      training_data.append(np.asarray(image))
  training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,
            GENERATE_SQUARE,IMAGE_CHANNELS))
  training_data = training_data.astype(np.float32)
  training_data = training_data / 127.5 - 1.


  print("Saving training image binary...")
  np.save(training_binary_path,training_data)
  elapsed = time.time()-start
  print (f'Image preprocess time: {hms_string(elapsed)}')
else:
  print("Loading previous training pickle...")
  training_data = np.load(training_binary_path)
# Out:
# Looking for file: /content/data/M/training_data_96_96.npy
# Loading previous training pickle...

# %%
train_datasetM= tf.data.Dataset.from_tensor_slices(training_data).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
train(train_datasetM, EPOCHS,DATA_PATHM)
# Out:
# Epoch1, gen loss=13.592447280883789,disc loss=5.356238842010498,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 24ms/step
# Epoch2, gen loss=9.509544372558594,disc loss=4.1374688148498535,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 20ms/step
# Epoch3, gen loss=6.623237133026123,disc loss=2.0175328254699707,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch4, gen loss=5.51495885848999,disc loss=1.7295180559158325,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 27ms/step
# Epoch5, gen loss=5.8298020362854,disc loss=1.3919601440429688,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 26ms/step
# Epoch6, gen loss=4.655811786651611,disc loss=1.061000943183899,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 27ms/step
# Epoch7, gen loss=6.665090560913086,disc loss=1.2027008533477783,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch8, gen loss=5.791861057281494,disc loss=1.1372594833374023,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch9, gen loss=5.184497356414795,disc loss=0.9502775073051453,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch10, gen loss=4.232022285461426,disc loss=0.5570789575576782,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch11, gen loss=4.307340621948242,disc loss=0.41763707995414734,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 29ms/step
# Epoch12, gen loss=5.102679252624512,disc loss=0.6973136067390442,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 20ms/step
# Epoch13, gen loss=4.6072258949279785,disc loss=0.24082374572753906,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 32ms/step
# Epoch14, gen loss=4.749780178070068,disc loss=0.2560369670391083,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 20ms/step
# Epoch15, gen loss=5.000976085662842,disc loss=0.5749106407165527,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch16, gen loss=5.405155181884766,disc loss=0.4586705267429352,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch17, gen loss=4.458323955535889,disc loss=0.24415530264377594,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch18, gen loss=4.466756820678711,disc loss=0.23380525410175323,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch19, gen loss=4.896081924438477,disc loss=0.3204857409000397,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch20, gen loss=4.736968994140625,disc loss=0.27151980996131897,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 32ms/step
# Epoch21, gen loss=5.349213123321533,disc loss=0.21705642342567444,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch22, gen loss=4.671561241149902,disc loss=0.185946986079216,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch23, gen loss=5.548189640045166,disc loss=0.10884380340576172,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch24, gen loss=5.6106085777282715,disc loss=0.1368637979030609,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch25, gen loss=5.246236324310303,disc loss=0.12288588285446167,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 20ms/step
# Epoch26, gen loss=5.889364242553711,disc loss=0.17207388579845428,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 20ms/step
# Epoch27, gen loss=5.983758449554443,disc loss=0.09298034757375717,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 32ms/step
# Epoch28, gen loss=5.068526744842529,disc loss=0.18327346444129944,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch29, gen loss=5.787206649780273,disc loss=0.20989225804805756,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 27ms/step
# Epoch30, gen loss=6.330460071563721,disc loss=0.061941999942064285,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch31, gen loss=6.10636043548584,disc loss=0.0796063169836998,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 22ms/step
# Epoch32, gen loss=6.272351264953613,disc loss=0.13930334150791168,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 20ms/step
# Epoch33, gen loss=6.080970764160156,disc loss=0.06847631186246872,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch34, gen loss=5.341717720031738,disc loss=0.10411207377910614,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch35, gen loss=6.399781703948975,disc loss=0.06146702170372009,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 37ms/step
# Epoch36, gen loss=5.541821002960205,disc loss=0.07236025482416153,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 29ms/step
# Epoch37, gen loss=6.845874786376953,disc loss=0.028363343328237534,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch38, gen loss=6.01837682723999,disc loss=0.06347665190696716,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 20ms/step
# Epoch39, gen loss=6.094997882843018,disc loss=0.03363758325576782,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch40, gen loss=6.369204044342041,disc loss=0.03254751116037369,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch41, gen loss=7.584936618804932,disc loss=0.02156084030866623,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 20ms/step
# Epoch42, gen loss=6.408824443817139,disc loss=0.10030154138803482,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch43, gen loss=6.528585910797119,disc loss=0.04338708519935608,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 35ms/step
# Epoch44, gen loss=6.2721028327941895,disc loss=0.0572286956012249,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 20ms/step
# Epoch45, gen loss=6.496741771697998,disc loss=0.03473649173974991,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch46, gen loss=7.7616119384765625,disc loss=0.016911417245864868,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 20ms/step
# Epoch47, gen loss=7.595456600189209,disc loss=0.01596364937722683,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch48, gen loss=6.2303900718688965,disc loss=0.02434135042130947,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 20ms/step
# Epoch49, gen loss=6.426758289337158,disc loss=0.03516937419772148,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch50, gen loss=7.162841796875,disc loss=0.01894422061741352,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 32ms/step

# %%
imgpathm="/content/data/M/1005.jpg"
Image.open(imgpathm)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128>

# %%
imgpathm="/content/data/M/output/train-18.png"
Image.open(imgpathm)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x464>

# %%
DATA_PATHE="/content/data/E"
training_binary_path = os.path.join(DATA_PATHE,
        f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}.npy')

print(f"Looking for file: {training_binary_path}")

if not os.path.isfile(training_binary_path):
  start = time.time()
  print("Loading training images...")

  training_data = []
  faces_path = os.path.join(DATA_PATHE)
  for filename in tqdm(os.listdir(faces_path)):
      path = os.path.join(faces_path,filename)
      image = Image.open(path).resize((GENERATE_SQUARE,
            GENERATE_SQUARE),Image.ANTIALIAS)
      training_data.append(np.asarray(image))
  training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,
            GENERATE_SQUARE,IMAGE_CHANNELS))
  training_data = training_data.astype(np.float32)
  training_data = training_data / 127.5 - 1.


  print("Saving training image binary...")
  np.save(training_binary_path,training_data)
  elapsed = time.time()-start
  print (f'Image preprocess time: {hms_string(elapsed)}')
else:
  print("Loading previous training pickle...")
  training_data = np.load(training_binary_path)
# Out:
# Looking for file: /content/data/E/training_data_96_96.npy
# Loading previous training pickle...

# %%
train_datasetE= tf.data.Dataset.from_tensor_slices(training_data).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
train(train_datasetE, EPOCHS,DATA_PATHE)
# Out:
# Epoch1, gen loss=14.909473419189453,disc loss=6.324597358703613,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 31ms/step
# Epoch2, gen loss=14.487262725830078,disc loss=2.04845929145813,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch3, gen loss=8.50989055633545,disc loss=1.154017448425293,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 21ms/step
# Epoch4, gen loss=10.267417907714844,disc loss=1.5547817945480347,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 28ms/step
# Epoch5, gen loss=8.087910652160645,disc loss=0.6517465710639954,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch6, gen loss=9.85794448852539,disc loss=1.6573901176452637,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 20ms/step
# Epoch7, gen loss=10.429522514343262,disc loss=1.1600850820541382,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 21ms/step
# Epoch8, gen loss=6.996984481811523,disc loss=0.5645903944969177,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch9, gen loss=6.340616703033447,disc loss=0.981370747089386,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch10, gen loss=5.854010105133057,disc loss=0.3465936779975891,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch11, gen loss=5.861446380615234,disc loss=0.1707269698381424,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 30ms/step
# Epoch12, gen loss=7.648299217224121,disc loss=0.5711629390716553,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch13, gen loss=5.682153224945068,disc loss=0.2384510487318039,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch14, gen loss=5.709132194519043,disc loss=0.19812846183776855,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch15, gen loss=7.370508193969727,disc loss=0.23315788805484772,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 22ms/step
# Epoch16, gen loss=7.183620929718018,disc loss=0.36990031599998474,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch17, gen loss=6.973733425140381,disc loss=0.13385824859142303,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 21ms/step
# Epoch18, gen loss=6.575459957122803,disc loss=0.11859121173620224,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 33ms/step
# Epoch19, gen loss=6.380207061767578,disc loss=0.14161677658557892,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch20, gen loss=6.9625725746154785,disc loss=0.6240320801734924,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 28ms/step
# Epoch21, gen loss=6.257093906402588,disc loss=0.21619796752929688,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch22, gen loss=7.347229957580566,disc loss=0.14323225617408752,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch23, gen loss=6.129587173461914,disc loss=0.189552903175354,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch24, gen loss=6.286074161529541,disc loss=0.12147698551416397,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch25, gen loss=5.336495876312256,disc loss=0.16092230379581451,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 17ms/step
# Epoch26, gen loss=5.956984519958496,disc loss=0.1377914547920227,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch27, gen loss=6.549956798553467,disc loss=0.07809581607580185,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 31ms/step
# Epoch28, gen loss=5.8647356033325195,disc loss=0.046444665640592575,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch29, gen loss=6.402356147766113,disc loss=0.05585004761815071,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch30, gen loss=6.248744964599609,disc loss=0.0726425051689148,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch31, gen loss=6.336337566375732,disc loss=0.07253076136112213,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch32, gen loss=6.07709264755249,disc loss=0.04871891811490059,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch33, gen loss=7.060152530670166,disc loss=0.15558013319969177,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 17ms/step
# Epoch34, gen loss=7.433294296264648,disc loss=0.13115248084068298,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 32ms/step
# Epoch35, gen loss=7.0171895027160645,disc loss=0.06630126386880875,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 17ms/step
# Epoch36, gen loss=7.5616536140441895,disc loss=0.04972197860479355,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 27ms/step
# Epoch37, gen loss=6.653385639190674,disc loss=0.041805531829595566,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch38, gen loss=7.119165420532227,disc loss=0.06737114489078522,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch39, gen loss=6.448659896850586,disc loss=0.042032189667224884,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch40, gen loss=7.494798183441162,disc loss=0.04716052860021591,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 17ms/step
# Epoch41, gen loss=6.879460334777832,disc loss=0.16502612829208374,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 17ms/step
# Epoch42, gen loss=7.323586940765381,disc loss=0.05084039270877838,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch43, gen loss=6.438908100128174,disc loss=0.04205365106463432,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 31ms/step
# Epoch44, gen loss=6.052186489105225,disc loss=0.06474554538726807,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 23ms/step
# Epoch45, gen loss=7.341519832611084,disc loss=0.18514209985733032,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch46, gen loss=7.671184539794922,disc loss=0.09238699823617935,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch47, gen loss=10.89333724975586,disc loss=0.3528853952884674,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch48, gen loss=7.584061622619629,disc loss=0.051813188940286636,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 20ms/step
# Epoch49, gen loss=7.337306976318359,disc loss=0.050322942435741425,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch50, gen loss=8.047538757324219,disc loss=0.08829699456691742,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 28ms/step

# %%
imgpathe="/content/data/E/1005.jpg"
Image.open(imgpathe)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128>

# %%
imgpathoe="/content/data/E/output/train-13.png"
Image.open(imgpathoe)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x464>

# %%
DATA_PATHQ="/content/data/Q"
training_binary_path = os.path.join(DATA_PATHQ,
        f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}.npy')

print(f"Looking for file: {training_binary_path}")

if not os.path.isfile(training_binary_path):
  start = time.time()
  print("Loading training images...")

  training_data = []
  faces_path = os.path.join(DATA_PATHQ)
  for filename in tqdm(os.listdir(faces_path)):
      path = os.path.join(faces_path,filename)
      image = Image.open(path).resize((GENERATE_SQUARE,
            GENERATE_SQUARE),Image.ANTIALIAS)
      training_data.append(np.asarray(image))
  training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,
            GENERATE_SQUARE,IMAGE_CHANNELS))
  training_data = training_data.astype(np.float32)
  training_data = training_data / 127.5 - 1.


  print("Saving training image binary...")
  np.save(training_binary_path,training_data)
  elapsed = time.time()-start
  print (f'Image preprocess time: {hms_string(elapsed)}')
else:
  print("Loading previous training pickle...")
  training_data = np.load(training_binary_path)
# Out:
# Looking for file: /content/data/Q/training_data_96_96.npy
# Loading previous training pickle...

# %%
train_datasetQ= tf.data.Dataset.from_tensor_slices(training_data).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
train(train_datasetQ, EPOCHS,DATA_PATHQ)
# Out:
# Epoch1, gen loss=18.300317764282227,disc loss=3.2695865631103516,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 28ms/step
# Epoch2, gen loss=13.973672866821289,disc loss=2.836198329925537,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 20ms/step
# Epoch3, gen loss=7.875738620758057,disc loss=1.3807059526443481,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 17ms/step
# Epoch4, gen loss=8.441815376281738,disc loss=0.9298605918884277,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch5, gen loss=9.337162971496582,disc loss=1.4458614587783813,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch6, gen loss=6.91049337387085,disc loss=0.7055615782737732,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 29ms/step
# Epoch7, gen loss=8.051661491394043,disc loss=0.7376380562782288,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 17ms/step
# Epoch8, gen loss=5.816797733306885,disc loss=0.43308719992637634,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 17ms/step
# Epoch9, gen loss=6.559449672698975,disc loss=0.3606206178665161,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch10, gen loss=6.359075546264648,disc loss=0.38150671124458313,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 17ms/step
# Epoch11, gen loss=6.165884017944336,disc loss=0.15629510581493378,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch12, gen loss=6.946399688720703,disc loss=0.22267748415470123,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch13, gen loss=5.913069248199463,disc loss=0.3059353530406952,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 26ms/step
# Epoch14, gen loss=5.326577186584473,disc loss=0.18887095153331757,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 21ms/step
# Epoch15, gen loss=6.187760353088379,disc loss=0.1337519884109497,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch16, gen loss=6.28236722946167,disc loss=0.1660597175359726,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch17, gen loss=6.531111240386963,disc loss=0.2714273929595947,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 21ms/step
# Epoch18, gen loss=7.108884334564209,disc loss=0.1332196742296219,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 33ms/step
# Epoch19, gen loss=7.447475910186768,disc loss=0.08034065365791321,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 20ms/step
# Epoch20, gen loss=7.2394938468933105,disc loss=0.09860199689865112,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 28ms/step
# Epoch21, gen loss=6.441379547119141,disc loss=0.1279914677143097,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 20ms/step
# Epoch22, gen loss=6.485467433929443,disc loss=0.0865805372595787,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch23, gen loss=8.151898384094238,disc loss=0.09646231681108475,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch24, gen loss=6.420207977294922,disc loss=0.07660042494535446,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 17ms/step
# Epoch25, gen loss=8.017313003540039,disc loss=0.05111317336559296,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch26, gen loss=8.231310844421387,disc loss=0.044675055891275406,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch27, gen loss=9.03937816619873,disc loss=0.28600141406059265,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 34ms/step
# Epoch28, gen loss=7.633408546447754,disc loss=0.07374745607376099,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 21ms/step
# Epoch29, gen loss=6.843973159790039,disc loss=0.04237312078475952,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 34ms/step
# Epoch30, gen loss=6.925075531005859,disc loss=0.053778693079948425,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch31, gen loss=7.3668131828308105,disc loss=0.026615912094712257,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch32, gen loss=7.113221168518066,disc loss=0.0544591061770916,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 19ms/step
# Epoch33, gen loss=8.322407722473145,disc loss=0.0447448194026947,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch34, gen loss=8.818441390991211,disc loss=0.044590748846530914,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 21ms/step
# Epoch35, gen loss=7.908308506011963,disc loss=0.02478952519595623,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch36, gen loss=7.898365020751953,disc loss=0.039841193705797195,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 30ms/step
# Epoch37, gen loss=7.610468864440918,disc loss=0.04930732026696205,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch38, gen loss=7.6321868896484375,disc loss=0.027353668585419655,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch39, gen loss=8.256361961364746,disc loss=0.015343802981078625,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 17ms/step
# Epoch40, gen loss=7.95070219039917,disc loss=0.02450336329638958,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch41, gen loss=7.486820220947266,disc loss=0.03066769801080227,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 17ms/step
# Epoch42, gen loss=7.812270164489746,disc loss=0.0223100446164608,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 27ms/step
# Epoch43, gen loss=8.60628604888916,disc loss=0.015584335662424564,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 31ms/step
# Epoch44, gen loss=10.625027656555176,disc loss=0.10387052595615387,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 17ms/step
# Epoch45, gen loss=11.647024154663086,disc loss=0.012832381762564182,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 29ms/step
# Epoch46, gen loss=9.489266395568848,disc loss=0.013547014445066452,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 21ms/step
# Epoch47, gen loss=8.582093238830566,disc loss=0.025369293987751007,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 17ms/step
# Epoch48, gen loss=8.6074857711792,disc loss=0.044582974165678024,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step
# Epoch49, gen loss=8.405776023864746,disc loss=0.027454253286123276,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 17ms/step
# Epoch50, gen loss=10.287651062011719,disc loss=0.012190965004265308,{hms_string(epoch_elapsed)}
# 1/1 [==============================] - 0s 18ms/step

# %%
imgpathq="/content/data/Q/1005.jpg"
Image.open(imgpathq)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128>

# %%
imgpathoq="/content/data/Q/output/train-11.png"
Image.open(imgpathoq)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x464>

# %%
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import numpy as np
from PIL import Image
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir="/content/data"
train_path=ImageDataGenerator(rescale=1/255.,
                              horizontal_flip=True,
                              shear_range=0.2,
                              zoom_range=0.2, )
valid_path=ImageDataGenerator(rescale=1./255, validation_split=0.2)

# %%
train_data = train_path.flow_from_directory(train_dir,
                                               target_size=(224, 224),
                                               color_mode='rgb',
                                               batch_size=32,
                                               class_mode='categorical',
                                               shuffle=True,
                                               subset = 'training')
valid_data = valid_path.flow_from_directory(train_dir,
                                           target_size=(224, 224),
                                           color_mode='rgb',
                                           batch_size=32,
                                           class_mode='categorical',
                                           shuffle=False,
                                           subset = 'validation')
# Out:
# Found 42250 images belonging to 35 classes.
# Found 8450 images belonging to 35 classes.

# %%
model = tf.keras.models.Sequential([
     tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu", input_shape=(224, 224, 3), strides=2),
    tf.keras.layers.Conv2D(32, 3, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(pool_size=2, padding="valid"),
    tf.keras.layers.Conv2D(32, 3, activation="relu", strides=2),
    tf.keras.layers.Conv2D(24, 3, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(pool_size=2, padding="valid"),
    tf.keras.layers.Conv2D(24, 3, activation="relu", strides=2),
    tf.keras.layers.Conv2D(16, 3, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(pool_size=2, padding="valid"),
    tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.05)),
    tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.05)),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(35, activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 111, 111, 32)      896
#
#  conv2d_11 (Conv2D)          (None, 109, 109, 32)      9248
#
#  batch_normalization_8 (Batc  (None, 109, 109, 32)     128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 54, 54, 32)       0
#  )
#
#  conv2d_12 (Conv2D)          (None, 26, 26, 32)        9248
#
#  conv2d_13 (Conv2D)          (None, 24, 24, 24)        6936
#
#  batch_normalization_9 (Batc  (None, 24, 24, 24)       96
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 24)       0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 5, 5, 24)          5208
#
#  conv2d_15 (Conv2D)          (None, 3, 3, 16)          3472
#
#  batch_normalization_10 (Bat  (None, 3, 3, 16)         64
#  chNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 16)         0
#  2D)
#
#  dense_2 (Dense)             (None, 1, 1, 128)         2176
#
#  dense_3 (Dense)             (None, 1, 1, 128)         16512
#
#  dropout_5 (Dropout)         (None, 1, 1, 128)         0
#
#  global_average_pooling2d (G  (None, 128)              0
#  lobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 35)                4515
#
# =================================================================
# Total params: 58,499
# Trainable params: 58,355
# Non-trainable params: 144
# _________________________________________________________________

# %%
model.compile(loss="categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001), metrics=["accuracy"])
model.fit(train_data, epochs=15, steps_per_epoch=len(train_data), validation_data=valid_data, validation_steps=len(valid_data), callbacks=[tf.keras.callbacks.EarlyStopping(min_delta=0.01, patience=2)])
# Out:
# Epoch 1/15
# 1321/1321 [==============================] - 515s 386ms/step - loss: 10.6673 - accuracy: 0.0626 - val_loss: 9.8434 - val_accuracy: 0.1366
# Epoch 2/15
# 1321/1321 [==============================] - 502s 380ms/step - loss: 9.1544 - accuracy: 0.1511 - val_loss: 8.4315 - val_accuracy: 0.2315
# Epoch 3/15
# 1321/1321 [==============================] - 502s 380ms/step - loss: 7.8445 - accuracy: 0.2574 - val_loss: 7.1513 - val_accuracy: 0.3798
# Epoch 4/15
# 1321/1321 [==============================] - 504s 381ms/step - loss: 6.6834 - accuracy: 0.3594 - val_loss: 6.0346 - val_accuracy: 0.4992
# Epoch 5/15
# 1321/1321 [==============================] - 505s 382ms/step - loss: 5.7017 - accuracy: 0.4497 - val_loss: 5.0706 - val_accuracy: 0.6396
# Epoch 6/15
# 1321/1321 [==============================] - 500s 378ms/step - loss: 4.8973 - accuracy: 0.5323 - val_loss: 4.2769 - val_accuracy: 0.7653
# Epoch 7/15
# 1321/1321 [==============================] - 504s 382ms/step - loss: 4.2395 - accuracy: 0.6086 - val_loss: 3.6363 - val_accuracy: 0.8451
# Epoch 8/15
# 1321/1321 [==============================] - 502s 380ms/step - loss: 3.7021 - accuracy: 0.6754 - val_loss: 3.1282 - val_accuracy: 0.8941
# Epoch 9/15
# 1321/1321 [==============================] - 507s 384ms/step - loss: 3.2561 - accuracy: 0.7327 - val_loss: 2.7249 - val_accuracy: 0.9219
# Epoch 10/15
# 1321/1321 [==============================] - 496s 376ms/step - loss: 2.9009 - accuracy: 0.7760 - val_loss: 2.4234 - val_accuracy: 0.9366
# Epoch 11/15
# 1321/1321 [==============================] - 501s 379ms/step - loss: 2.5996 - accuracy: 0.8139 - val_loss: 2.1489 - val_accuracy: 0.9488
# Epoch 12/15
# 1321/1321 [==============================] - 498s 377ms/step - loss: 2.3507 - accuracy: 0.8455 - val_loss: 1.9415 - val_accuracy: 0.9630
# Epoch 13/15
# 1321/1321 [==============================] - 491s 372ms/step - loss: 2.1428 - accuracy: 0.8714 - val_loss: 1.7669 - val_accuracy: 0.9770
# Epoch 14/15
# 1321/1321 [==============================] - 495s 375ms/step - loss: 1.9693 - accuracy: 0.8917 - val_loss: 1.6121 - val_accuracy: 0.9806
# Epoch 15/15
# 1321/1321 [==============================] - 496s 375ms/step - loss: 1.8168 - accuracy: 0.9094 - val_loss: 1.4941 - val_accuracy: 0.9878

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
predictions = model.predict(valid_data)
true_labels = valid_data.classes
predicted_labels = np.argmax(predictions, axis=1)
confusion_mat = confusion_matrix(true_labels, predicted_labels)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='Blues', square=True, xticklabels=True, yticklabels=True)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
class_names = list(valid_data.class_indices.keys())
print(classification_report(true_labels, predicted_labels, target_names=class_names))
# Out:
# 265/265 [==============================] - 12s 46ms/step
#               precision    recall  f1-score   support
#
#            1       1.00      0.95      0.97       250
#            2       1.00      1.00      1.00       240
#            3       1.00      1.00      1.00       240
#            4       1.00      1.00      1.00       240
#            5       0.98      1.00      0.99       240
#            6       1.00      1.00      1.00       240
#            7       1.00      1.00      1.00       240
#            8       1.00      0.98      0.99       250
#            9       1.00      1.00      1.00       240
#            A       1.00      1.00      1.00       240
#            B       0.99      1.00      1.00       240
#            C       1.00      0.95      0.97       240
#            D       0.99      1.00      1.00       240
#            E       1.00      1.00      1.00       250
#            F       1.00      1.00      1.00       240
#            G       1.00      1.00      1.00       240
#            H       0.96      1.00      0.98       240
#            I       0.97      0.97      0.97       240
#            J       0.91      1.00      0.95       240
#            K       0.99      1.00      0.99       240
#            L       0.94      1.00      0.97       240
#            M       1.00      1.00      1.00       250
#            N       1.00      1.00      1.00       240
#            O       1.00      1.00      1.00       240
#            P       1.00      1.00      1.00       240
#            Q       0.97      1.00      0.98       250
#            R       1.00      1.00      1.00       240
#            S       1.00      0.92      0.96       240
#            T       0.91      0.85      0.88       240
#            U       1.00      1.00      1.00       240
#            V       0.98      1.00      0.99       240
#            W       1.00      0.95      0.98       240
#            X       1.00      1.00      1.00       240
#            Y       1.00      1.00      1.00       240
#            Z       1.00      1.00      1.00       240
#
#     accuracy                           0.99      8450
#    macro avg       0.99      0.99      0.99      8450
# weighted avg       0.99      0.99      0.99      8450
